# %%
import nemo.collections.asr as nemo_asr
asr_model = nemo_asr.models.EncDecRNNTBPEModel.from_pretrained(model_name="nvidia/parakeet-rnnt-1.1b")
# Out:
# Setting ds_accelerator to cuda (auto detect)
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 import nemo.collections.asr as nemo_asr                                                      │
# │   2 asr_model = nemo_asr.models.EncDecRNNTBPEModel.from_pretrained(model_name="nvidia/parake     │
# │   3                                                                                              │
# │                                                                                                  │
# │ /Users/iskander/miniconda3/lib/python3.10/site-packages/nemo/collections/asr/__init__.py:15 in   │
# │ <module>                                                                                         │
# │                                                                                                  │
# │   12 # See the License for the specific language governing permissions and                       │
# │   13 # limitations under the License.                                                            │
# │   14                                                                                             │
# │ ❱ 15 from nemo.collections.asr import data, losses, models, modules                              │
# │   16 from nemo.package_info import __version__                                                   │
# │   17                                                                                             │
# │   18 # Set collection version equal to NeMo version.                                             │
# │                                                                                                  │
# │ /Users/iskander/miniconda3/lib/python3.10/site-packages/nemo/collections/asr/losses/__init__.py: │
# │ 15 in <module>                                                                                   │
# │                                                                                                  │
# │   12 # See the License for the specific language governing permissions and                       │
# │   13 # limitations under the License.                                                            │
# │   14                                                                                             │
# │ ❱ 15 from nemo.collections.asr.losses.angularloss import AngularSoftmaxLoss                      │
# │   16 from nemo.collections.asr.losses.audio_losses import SDRLoss                                │
# │   17 from nemo.collections.asr.losses.ctc import CTCLoss                                         │
# │   18 from nemo.collections.asr.losses.lattice_losses import LatticeLoss                          │
# │                                                                                                  │
# │ /Users/iskander/miniconda3/lib/python3.10/site-packages/nemo/collections/asr/losses/angularloss. │
# │ py:18 in <module>                                                                                │
# │                                                                                                  │
# │   15                                                                                             │
# │   16 import torch                                                                                │
# │   17                                                                                             │
# │ ❱ 18 from nemo.core.classes import Loss, Typing, typecheck                                       │
# │   19 from nemo.core.neural_types import LabelsType, LogitsType, LossType, NeuralType             │
# │   20                                                                                             │
# │   21 __all__ = ['AngularSoftmaxLoss']                                                            │
# │                                                                                                  │
# │ /Users/iskander/miniconda3/lib/python3.10/site-packages/nemo/core/__init__.py:16 in <module>     │
# │                                                                                                  │
# │   13 # limitations under the License.                                                            │
# │   14                                                                                             │
# │   15 import nemo.core.neural_types                                                               │
# │ ❱ 16 from nemo.core.classes import *                                                             │
# │   17                                                                                             │
# │                                                                                                  │
# │ /Users/iskander/miniconda3/lib/python3.10/site-packages/nemo/core/classes/__init__.py:30 in      │
# │ <module>                                                                                         │
# │                                                                                                  │
# │   27 │   typecheck,                                                                              │
# │   28 )                                                                                           │
# │   29 from nemo.core.classes.dataset import Dataset, IterableDataset                              │
# │ ❱ 30 from nemo.core.classes.exportable import Exportable, ExportFormat                           │
# │   31 from nemo.core.classes.loss import Loss                                                     │
# │   32 from nemo.core.classes.mixins import access_mixins, adapter_mixins                          │
# │   33 from nemo.core.classes.modelPT import ModelPT                                               │
# │                                                                                                  │
# │ /Users/iskander/miniconda3/lib/python3.10/site-packages/nemo/core/classes/exportable.py:18 in    │
# │ <module>                                                                                         │
# │                                                                                                  │
# │    15 from typing import List, Union                                                             │
# │    16                                                                                            │
# │    17 import torch                                                                               │
# │ ❱  18 from pytorch_lightning.core.module import _jit_is_scripting                                │
# │    19                                                                                            │
# │    20 from nemo.core.classes import typecheck                                                    │
# │    21 from nemo.core.utils.neural_type_utils import get_dynamic_axes, get_io_names               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ImportError: cannot import name '_jit_is_scripting' from 'pytorch_lightning.core.module'
# (/Users/iskander/miniconda3/lib/python3.10/site-packages/pytorch_lightning/core/module.py)
